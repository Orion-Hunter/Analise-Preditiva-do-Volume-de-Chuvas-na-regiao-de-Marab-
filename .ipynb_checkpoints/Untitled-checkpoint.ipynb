# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import config
import plotly.express as px
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
file = pd.ExcelFile('Data/Data.xlsx')
data = pd.read_excel(file, 'DATA')
prm = pd.read_excel(file, 'PRP-MENSAL')
data
# Out:
#           DATA  TSM-AN1  TSM-AN2  TSM-AN3  TSM-AN4  TSM-AN5  TSM-AN6  TSM-AN7  \
# 0   1982-01-01  26.0098  25.3862  24.3421  22.9730  26.8484  26.1652  25.2629
# 1   1982-02-01  25.4937  24.6246  23.7060  22.2753  26.4223  25.4757  24.6380
# 2   1982-03-01  25.3498  24.4863  23.5340  22.1519  26.3487  25.4243  24.6487
# 3   1982-04-01  25.7790  24.6510  23.4159  22.3043  26.6982  25.3215  24.6814
# 4   1982-05-01  26.6424  25.5152  24.1482  23.0335  27.3998  26.1700  25.3244
# ..         ...      ...      ...      ...      ...      ...      ...      ...
# 462 2020-08-01  28.4721  27.3896  26.5677  26.1410  28.9465  28.2160  27.9531
# 463 2020-09-01  28.6614  27.6689  27.1493  27.4002  29.1244  28.3055  28.1015
# 464 2020-10-01  28.4023  27.6131  27.3763  27.2015  28.9573  28.2666  27.9994
# 465 2020-11-01  27.6801  27.0970  26.6494  26.2036  28.3641  27.7229  27.4578
# 466 2020-12-01  27.2088  26.4270  25.4546  24.6123  28.1633  27.3789  26.5234
#
# ...

# %%
prm
# Out:
#           DATA       PRM1      PRM2      PRM3      PRM4      PRM5      PRM6  \
# 0   1982-01-01  425.21400  411.5660  361.5420  319.0600  364.3730  472.6170
# 1   1982-02-01  277.56100  295.2290  340.5010  356.4590  353.0050  340.7350
# 2   1982-03-01  256.49000  267.5700  269.8620  262.2630  267.3230  304.2560
# 3   1982-04-01  363.14100  363.5890  318.9020  248.4550  232.4990  248.5390
# 4   1982-05-01   49.84450   64.8544   97.7188  117.4110  113.9240  105.4870
# ..         ...        ...       ...       ...       ...       ...       ...
# 462 2020-08-01   34.93580   38.3834   37.7947   27.3630   16.3128   14.6326
# 463 2020-09-01    9.46471    7.1396    9.7036   18.6741   30.2171   26.4470
# 464 2020-10-01   22.29700   21.6361   23.6413   31.2868   45.8397   81.8507
# 465 2020-11-01  172.26400  223.8920  224.1900  223.6430  214.3870  204.6460
# 466 2020-12-01  124.39400  137.1280  158.1460  158.1050  149.7240  110.2550
#
# ...

# %%
x = data['DATA'].values
y = data['TSM-AN1'].values
    
df = pd.DataFrame({'Data': x, 'Atlântico Norte - Área 1': y})

fig = px.scatter(df, x='Data', y='Atlântico Norte - Área 1')
fig.show()

# %%
data['DATA'] = data['DATA'].astype('string')
prm['DATA'] = prm['DATA'].astype('string')

data.dtypes
# Out:
# DATA         string
# TSM-AN1     float64
# TSM-AN2     float64
# TSM-AN3     float64
# TSM-AN4     float64
#              ...
# TSM-PS34    float64
# TSM-N1      float64
# TSM-N2      float64
# TSM-N3      float64
# TSM-N4      float64
# Length: 97, dtype: object

# %%
data
# Out:
#            DATA  TSM-AN1  TSM-AN2  TSM-AN3  TSM-AN4  TSM-AN5  TSM-AN6  \
# 0    1982-01-01  26.0098  25.3862  24.3421  22.9730  26.8484  26.1652
# 1    1982-02-01  25.4937  24.6246  23.7060  22.2753  26.4223  25.4757
# 2    1982-03-01  25.3498  24.4863  23.5340  22.1519  26.3487  25.4243
# 3    1982-04-01  25.7790  24.6510  23.4159  22.3043  26.6982  25.3215
# 4    1982-05-01  26.6424  25.5152  24.1482  23.0335  27.3998  26.1700
# ..          ...      ...      ...      ...      ...      ...      ...
# 462  2020-08-01  28.4721  27.3896  26.5677  26.1410  28.9465  28.2160
# 463  2020-09-01  28.6614  27.6689  27.1493  27.4002  29.1244  28.3055
# 464  2020-10-01  28.4023  27.6131  27.3763  27.2015  28.9573  28.2666
# 465  2020-11-01  27.6801  27.0970  26.6494  26.2036  28.3641  27.7229
# 466  2020-12-01  27.2088  26.4270  25.4546  24.6123  28.1633  27.3789
#
#      TSM-AN7  TSM-AN8  TSM-AN9  ...  TSM-PS29  TSM-PS30  TSM-PS31  TSM-PS32  \
# ...

# %%
data.loc[data['DATA'].str.contains('1982')]
# Out:
#           DATA  TSM-AN1  TSM-AN2  TSM-AN3  TSM-AN4  TSM-AN5  TSM-AN6  TSM-AN7  \
# 0   1982-01-01  26.0098  25.3862  24.3421  22.9730  26.8484  26.1652  25.2629
# 1   1982-02-01  25.4937  24.6246  23.7060  22.2753  26.4223  25.4757  24.6380
# 2   1982-03-01  25.3498  24.4863  23.5340  22.1519  26.3487  25.4243  24.6487
# 3   1982-04-01  25.7790  24.6510  23.4159  22.3043  26.6982  25.3215  24.6814
# 4   1982-05-01  26.6424  25.5152  24.1482  23.0335  27.3998  26.1700  25.3244
# 5   1982-06-01  27.2580  26.1525  24.8852  23.6206  27.4524  26.6441  25.8060
# 6   1982-07-01  27.3333  26.2110  25.1921  24.1687  27.5218  27.1376  26.5896
# 7   1982-08-01  27.7096  26.7311  25.7745  25.2591  28.0204  27.4469  27.4126
# 8   1982-09-01  28.0901  27.3321  26.3709  25.7288  28.3239  28.0326  27.6989
# 9   1982-10-01  27.6497  27.0764  26.5369  25.7747  28.0367  27.5666  27.4533
# 10  1982-11-01  27.0988  26.4961  25.8143  25.0486  27.4278  26.9541  26.5780
# ...

# %%
import plotly.graph_objects as go

anos = [1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,
        2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]


df = prm.loc[data['DATA'].str.contains('2005')] 
df2 = prm.loc[data['DATA'].str.contains('2006')]
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']


bars = []

for ano in anos:
    x = prm.loc[prm['DATA'].str.contains(str(ano))]['DATA'].values
    y = prm.loc[prm['DATA'].str.contains(str(ano))]['PRM2'].values
    bars.append(px.scatter(x=x, y=y, size=np.ceil(y / sum(y) * 100)))

fig = go.Figure(data=bars)
#fig.update_layout(barmode='group')

#fig = px.bar(df, x='DATA', y='PRM1')
#fig2 = px.bar(df2, x='DATA', y='PRM1')
fig.show()
#fig2.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-109e9cd57b13> in <module>
#      17     bars.append(px.scatter(x=x, y=y, size=np.ceil(y / sum(y) * 100)))
#      18
# ---> 19 fig = go.Figure(data=bars)
#      20 #fig.update_layout(barmode='group')
#      21
#
# ~/.local/lib/python3.8/site-packages/plotly/graph_objs/_figure.py in __init__(self, data, layout, frames, skip_invalid, **kwargs)
#     594             is invalid AND skip_invalid is False
#     595         """
# --> 596         super(Figure, self).__init__(data, layout, frames, skip_invalid, **kwargs)
#     597
#     598     def add_area(
#
# ~/.local/lib/python3.8/site-packages/plotly/basedatatypes.py in __init__(self, data, layout_plotly, frames, skip_invalid, **kwargs)
#     514
#     515         # ### Import traces ###
# --> 516         data = self._data_validator.validate_coerce(
# ...

# %%
df
# Out:
#           DATA      PRM1      PRM2       PRM3       PRM4       PRM5  \
# 276 2005-01-01  228.8450  192.4850  178.70200  181.42400  190.36100
# 277 2005-02-01  343.4600  283.9300  273.32000  282.00100  292.37500
# 278 2005-03-01  432.4760  296.0130  246.64000  238.01600  236.50200
# 279 2005-04-01  250.0760  172.8590  149.79800  147.00900  144.46700
# 280 2005-05-01  208.3840  192.1110  174.39600  157.34900  137.95300
# 281 2005-06-01   42.1363   18.2488   10.02870    8.33345    7.34769
# 282 2005-07-01   39.7761   17.1477    6.63062    5.58356    3.65906
# 283 2005-08-01   12.1278   13.0348   12.73190    9.87225    6.60506
# 284 2005-09-01   26.2983   29.5551   41.19020   58.19170   70.97850
# 285 2005-10-01   19.6231   39.6224   45.69790   41.41650   32.87890
# 286 2005-11-01   34.8777   50.8899   86.46380  122.31600  139.19900
# 287 2005-12-01  346.5960  299.3260  292.13300  300.65500  297.95200
#
#           PRM6      PRM7       PRM8       PRM9  ...      PRM15       PRM16  \
# ...

# %%
# Out:
# array([23., 17., 15., 21.,  4.,  2.,  1.,  3.,  4.,  5.,  2., 10.])

# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
X, y = load_diabetes(return_X_y=True)
regressor = DecisionTreeRegressor(random_state=0)
cross_val_score(regressor, X, y, cv=10)
# Out:
# array([-0.39292219, -0.46749346,  0.02768473,  0.06441362, -0.50323135,
#         0.16437202,  0.11242982, -0.73798979, -0.30953155, -0.00137327])

# %%
# Out:
# (array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990842, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06832974, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286377, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04687948,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452837, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00421986,  0.00306441]]),
#  array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...
