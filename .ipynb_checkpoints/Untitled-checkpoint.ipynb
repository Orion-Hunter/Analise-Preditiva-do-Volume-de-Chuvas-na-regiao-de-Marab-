# %%
import numpy as np
import pandas as pd
from scipy import stats as st
import autokeras as ak
#import autosklearn.classification as aml
#from sklearn.multioutput import MultiOutputClassifier
#from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
# Out:
# /home/fabricio/.cache/pypoetry/virtualenvs/modelo-preditor-A4158a_0-py3.9/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# 2021-09-18 07:18:39.424001: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-09-18 07:18:39.424042: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
pip install scipy
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/home/fabricio/.cache/pypoetry/virtualenvs/modelo-preditor-A4158a_0-py3.8/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
data = pd.read_excel("output/data/base_selecionada(dropna).xlsx", index_col=[0])
#ata = pd.read_excel('prm1.xlsx')
#data = data.drop(data.columns[0])
data = data.set_index('Data')
data
# Out:
#             TSM-NI3(1)  TSM-NI3(3)  TSM-NI3(4)  TSM-NI3(2)  TSM-NI3(5)  \
# Data
# 1983-01-01       29.15       29.38       29.16       29.23       29.04
# 1983-02-01       29.00       29.23       29.38       29.15       29.16
# 1983-03-01       28.79       29.15       29.23       29.00       29.38
# 1983-04-01       28.76       29.00       29.15       28.79       29.23
# 1983-05-01       28.85       28.79       29.00       28.76       29.15
# ...                ...         ...         ...         ...         ...
# 2020-08-01       28.83       28.94       29.29       29.07       29.22
# 2020-09-01       28.47       29.07       28.94       28.83       29.29
# 2020-10-01       28.29       28.83       29.07       28.47       28.94
# 2020-11-01       27.89       28.47       28.83       28.29       29.07
# 2020-12-01       27.91       28.29       28.47       27.89       28.83
#
#             TSM-NI3(6)  TSM-NI3(7)  TSM-NI3(11)  TSM-NI3(10)  TSM-NI4(6)  ...  \
# ...

# %%
X = data.drop(columns=['PRM1', 
                       'PRM2', 'PRM3', 'PRM4', 'PRM5', 'PRM6', 'PRM7',
                       'PRM8', 'PRM9', 'PRM10', 'PRM11', 'PRM12', 'PRM13', 'PRM14', 'PRM15',
                       'PRM16', 'PRM17', 'PRM18', 'PRM19', 'PRM20', 'PRM21', 'PRM22', 'PRM23',
                       'PRM24'])
y = data[['PRM1', 
          'PRM2', 'PRM3', 'PRM4', 'PRM5', 'PRM6', 'PRM7',
           'PRM8', 'PRM9', 'PRM10', 'PRM11', 'PRM12', 'PRM13', 'PRM14', 'PRM15',
           'PRM16', 'PRM17', 'PRM18', 'PRM19', 'PRM20', 'PRM21', 'PRM22', 'PRM23',
           'PRM24']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
model = ak.StructuredDataClassifier(
    multi_label=True,
    project_name="modelo",
    max_trials=150,
    directory="output/model",
    objective="val_accuracy",
    overwrite=True)

# %%
model.fit(X_train, y_train)
# Out:
# Trial 26 Complete [00h 01m 46s]
# val_accuracy: 0.380952388048172
#
# Best val_accuracy So Far: 0.380952388048172
# Total elapsed time: 00h 56m 11s
#
# Search: Running Trial #27
#
# Hyperparameter    |Value             |Best Value So Far
# structured_data...|True              |True
# structured_data...|False             |False
# structured_data...|2                 |2
# structured_data...|32                |32
# structured_data...|0                 |0
# structured_data...|32                |32
# classification_...|0                 |0
# optimizer         |sgd               |sgd
# learning_rate     |2e-05             |0.001
# structured_data...|16                |None
#
# Epoch 1/1000
# 8/8 [==============================] - 1s 44ms/step - loss: 0.7049 - accuracy: 0.0352 - val_loss: 0.7019 - val_accuracy: 0.0476
# Epoch 2/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.7049 - accuracy: 0.0352 - val_loss: 0.7018 - val_accuracy: 0.0476
# Epoch 3/1000
# ...
